# %% [markdown]
# # twcu11 クラスタリング

# %% [markdown]
# ## クラスタリング
# 参考->slide12

# %% [markdown]
# ## アヤメ= iris のデータでクラスタリング
#
# slide12.pptx slide 23
#
# - データの準備
# - アヤメのデータを使用する
# - setosaを10件、versicolorを10件、verginicaを10件抜き出す
# - 質的変数のSpeciesを削除する
# - 階層的クラスター分析
# - 非階層的クラスター分析

# %%
data(iris)
iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %%
#  3つの品種から10件ずつデータを抽出
iris2 <- iris[ c(1:10, 51:60, 101:110),  ]
iris2
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 51  7.0          3.2         4.7          1.4         versicolor
# 52  6.4          3.2         4.5          1.5         versicolor
# 53  6.9          3.1         4.9          1.5         versicolor
# 54  5.5          2.3         4.0          1.3         versicolor
# ...

# %%
#  質的変数のSpeciesを削除
iris3 <- iris2[ , -5 ]
head(iris3)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 5.1          3.5         1.4          0.2
# 2 4.9          3.0         1.4          0.2
# 3 4.7          3.2         1.3          0.2
# 4 4.6          3.1         1.5          0.2
# 5 5.0          3.6         1.4          0.2
# 6 5.4          3.9         1.7          0.4

# %%
# 距離行列をもとめる


iris.dist <- dist( iris3, method = "euclidean" )
# iris.dist <- dist( iris3, method = "manhattan" )
# iris.dist <- dist( iris3, method = "maximum" )

# %%
iris.dist
# Out:
#             1         2         3         4         5         6         7
# 2   0.5385165
# 3   0.5099020 0.3000000
# 4   0.6480741 0.3316625 0.2449490
# 5   0.1414214 0.6082763 0.5099020 0.6480741
# 6   0.6164414 1.0908712 1.0862780 1.1661904 0.6164414
# 7   0.5196152 0.5099020 0.2645751 0.3316625 0.4582576 0.9949874
# 8   0.1732051 0.4242641 0.4123106 0.5000000 0.2236068 0.7000000 0.4242641
# 9   0.9219544 0.5099020 0.4358899 0.3000000 0.9219544 1.4594520 0.5477226
# 10  0.4690416 0.1732051 0.3162278 0.3162278 0.5291503 1.0099505 0.4795832
# 51  4.0037482 4.0963398 4.2766810 4.1773197 4.0607881 3.6124784 4.2308392
# 52  3.6166283 3.6864617 3.8496753 3.7336309 3.6633318 3.2465366 3.7854986
# 53  4.1641326 4.2367440 4.4158804 4.3058100 4.2190046 3.7868192 4.3669211
# 54  3.0935417 2.9698485 3.1543621 2.9849623 3.1480152 2.9444864 3.1272992
# 55  3.7920970 3.8118237 3.9974992 3.8729833 3.8496753 3.4698703 3.9560081
# ...

# %%
# 階層クラスタリングをする
# hc1 ward法 ward slide 16
# hc2 最近隣 single -> slide 12
# hc3 最遠隣 complete -> silde 13
# hc4 重心 centroid -> slide 15

res.hc1 <- hclust( iris.dist, method = "ward.D2" )
res.hc2 <- hclust( iris.dist, method = "single" )
res.hc3 <- hclust( iris.dist, method = "complete" )
res.hc4 <- hclust( iris.dist, method = "centroid" )

# %%
#  デンドログラムの作図
plot( res.hc1, hang = -1 )
#  デンドログラムの分割
rect.hclust( res.hc1, k = 3)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
#  デンドログラムの作図
plot( res.hc2, hang = -1 )
#  デンドログラムの分割
rect.hclust( res.hc2, k = 3)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
#  デンドログラムの作図
plot( res.hc3, hang = -1 )
#  デンドログラムの分割
rect.hclust( res.hc3, k = 3)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
#  デンドログラムの作図
plot( res.hc4, hang = -1 )
#  デンドログラムの分割
rect.hclust( res.hc4, k = 3)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## 考えてみよう
#
# - どれが一番うまくいっていますか？
# - どうしてうまくいっている？
# - それはなぜ？

# %% [markdown]
# 回答を文章で記入しましょう

# %% [markdown]
# # K-means をやってみよう
#
# sildie 27

# %%
# ここでやってみよう
# 必要ならセルは追加してください

# %% [markdown]
# # 課題をやってみよう
#
# slide 28

# %%
# ここでやってみよう
# 必要ならセルは追加してください
