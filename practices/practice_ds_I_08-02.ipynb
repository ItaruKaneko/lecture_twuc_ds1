# %% [markdown]
# # practice_ds_I_08-02
#
# ( twuc3_4 データサイエンスIIA 第3-4回から移動)
#
# データサイエンスIIA 第3-4回 演習用 jupyter note
#
# 自分のgoogle driveにコピーしてから利用してください。

# %% [markdown]
# ## 1 参照スライド
#
# 参照スライド: ocha_slides/slides/slide05.pptx
#
# 参照スライド: ocha_slides/slides/slide08.pptx

# %% [markdown]
# ## 2 寺院のデータ

# %% [markdown]
# ### 課題1 寺院のデータ
#
# slide05.pptx
#
# 余力のある人
#
# 18ページ～21ページを見て R で実践、に従って data1 を作って、その次のセルは飛ばして次に進みましょう。
#
# わからない人は、2番目のセルを実行すれば次に進めます。
#
# 参考: データフレームについては practice2 で練習しました。

# %%
# 課題1回答欄(余裕のある人)

# %%
# 課題1のヒント(自力でできない人はこちらを実行してください。上に記入した人はこちらは実行しないでください。)
flag="答えを利用"
x<- c( 1.832, 1.777, 1.754, 1.791, 1.823, 2.066, 1.681, 1.806, 1.729, 1.958, 1.967, 1.915, 1.897, 2.175, 1.892 )
y<- c( 1.64, 1.785, 1.527, 1.502, 1.502, 1.766, 1.505, 1.523, 1.52, 1.64, 1.588, 1.581, 1.511, 1.745, 1.598 )
z<- c( "出雲国分寺", "上総国分寺", "百済廃寺", "興福寺（中）", "興福寺（東）", "相模国分寺", "信濃国分寺", "信濃国分尼寺", "下野国分寺", "唐招提寺", "東大寺", "遠江国分寺", "三河国分尼寺", "武蔵国分寺", "陸奥国分寺" )
data1 <- data.frame( 金堂の比 = x, 基壇の比 = y )
rownames(data1) <- z
print(flag)
# Out:
# [1] "答えを利用"

# %% [markdown]
# ### 課題2 6-7 世紀建立の7寺院の寸法比
#
# スライドのデータを以下のようなデータフレームにしてください。
#
# data2 <- data.frame(世紀=century, 堂の比 = x, 基壇の比 = y)

# %%
# 課題2回答欄(余裕のある人)

# %%
#課題2のヒント(自力でできない人はこちらを実行してください。上に記入した人はこちらは実行しないでください。)
flag2="課題2の答えを利用"
century <- c(6,7,7,7,7,7,7)
x <- c(1.418,1.798,2.184,1.274,1.250,1.290,1.255)
y <- c(1.324,1.380,1.866,1.216,1.227,1.196,1.157)
z = c( "飛鳥寺", "崇福寺", "大宮大寺跡", "当麻寺", "中宮寺跡", "法隆寺", "山田寺跡" )
## 次の行を完成させましょう

#data2 <- data.frame( # この後をいれて完成させましょう
data2 <- data.frame(世紀=century, 堂の比 = x, 基壇の比 = y)

rownames(data2) <- z
print(flag2)
# Out:
# [1] "課題2の答えを利用"

# %% [markdown]
# ### 課題3 t 検定を行う
# slide08 の 3ページの中間レポートの設問1の課題をやってみましょう。

# %%
# 課題3回答欄

# %% [markdown]
# ### 課題4 95% 信頼区間
#
# slide08 の 3ページの中間レポートの設問2の課題をやってみましょう。
#
# (後期には説明していないが、前期にやったと思うのでできる人やはってみましょう。知っていれば簡単ですよね。)

# %%
# 課題4 回答連

# %% [markdown]
# ## 3 二つの変数の関係
#
# slide08 の 6-8 頁を参照

# %% [markdown]
# ### 課題5 回帰分析
#
# slide08.pptx 12ページ参照
#
# carsデータを読んで回帰分析をしてください。

# %%
#課題5 回答欄

# carsデータを読む
data(cars) # この式を完成する

# cars の回帰分析を実行
res.lm1 <-  lm( dist ~ speed, data = cars )

res.lm1

# %%
summary(res.lm1)

# %% [markdown]
# 可視化してみる

# %%
plot(cars)

# %% [markdown]
# 以下でも同じ

# %%
plot(dist ~ speed, data = cars)

# %% [markdown]
# 回帰式を追加する
#
# plot は cars を plot している.
# abline は plot の上に追記するが、データは lm1 を使っている。

# %%
plot(dist ~ speed, data = cars)
abline(res.lm1, col="red")

# %% [markdown]
# 予測をしてみる

# %%
unknown.data = data.frame(speed = c(5,6,21))
predict(res.lm1, unknown.data)

# %% [markdown]
# ### 課題6 別の予測をしてみる
#
# 速度1, 10, 25 の場合を予測してみよ

# %%
# 回答欄 (このセルに予測のプログラムを完成する)

# %% [markdown]
# ### 課題7 帰無仮説とp-value の確認
#
# 以下のセルにテキストで、帰無仮説が何であって、p-value が何であって、したがってどう結果を説明できるかを書いてください。

# %% [markdown]
# 課題7 回答欄
#
# この下に回答を文章で記入してください。
# ダブルクリックすると編集できます。
#
# 改行は一行空けてください。
#
# これはノーヒント。できる人だけでかまいません。
#
# 無理にやらなくてもかまいませんが、そこそこがんばってみましょう。

# %% [markdown]
# ### 課題8 オゾン層
#
# slide08 のページ16-19 を実行しなさい
#
# コードセルは必要なだけ追加しなさい

# %%
# 課題8 回答例
data(airquality)
hist(airquality$Ozone)

# %%
hist(airquality$Solar.R)

# %%
hist(airquality$Wind)

# %%
hist(airquality$Temp)

# %%
model1 <- lm( Ozone ~ Temp, data= airquality)
plot(Ozone ~ Temp, data= airquality)
abline(model1, col="red")

# %% [markdown]
# ## 課題9 従業員の上司に対する満足度
#
# slide08 の ページ20-22
#
# 従業員の上司に対する満足度を予測する
#
# の計算をしてみてください。
#
# これはノーヒント。できる人だけでかまいません。

# %%
# 課題8 回答欄
