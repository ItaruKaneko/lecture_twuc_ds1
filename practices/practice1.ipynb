# %% [markdown]
# # R 言語の入門
#
# このシートは自習学習で本講義で必要なR言語の機能を一通り学びます。

# %% [markdown]
# # 1 変数と代入
#
# x, y, z のような文字は変数をあらわします。
#
# x <- 3 は変数にxという変数に3という数値を記憶させることを意味します。

# %%
x <- 3
print(x)

# %% [markdown]
# 今使っているのは Jupyter Notebook というプログラミング環境で、上にあるような枠をセルといいます。セルにはプログラムコードを記入し、左側の実行ボタンで実行すると、セルの下に出力が表示されます。
#
# Jupyter Notebook では、セルを実行した後も変数の値は残っています。ですから以下の結果も3になります。

# %%
print(x)

# %% [markdown]
# そしてyはまだ定義されていないから以下はエラーになります。

# %%
print(y)

# %% [markdown]
# 同じ変数に異なる値を代入することも可能です。再度代入を行うと値は上書きされて、古い値は捨てられます。

# %%
x <- 3
y <- x
x <- 100
print(x)
print(y)

# %% [markdown]
# 上の例では、x に新しい値が代入される前に古い値をyに代入してあったから、y の値は100 ではなく、3になります。
# 一方下の例では2行目と3行目をいれかえただけですが、x,yとも100になっています。

# %%
x <- 2
x <- 99
y <- x
print(x)
print(y)

# %% [markdown]
# このようにプログラミングでは命令の順序が大きな意味を持ちますので、代入が順序を追っておこなわれることに注意してください。

# %% [markdown]
# 次に変数名について確認しましょう。
# 変数名は、英字で始まること、そして英字、「_」下線、数字であらわします。
# 例を示します。
#
# 長いスペルでも問題ありません。
#
# totemo_mnagai_namaeno_hensu
#
# という変数も作れます。

# %%
x <- 123
totemo_nagai_namaeno_hensu <- x
p456 <- totemo_nagai_namaeno_hensu
print(p456)

# %% [markdown]
# でも以下はエラーになります。

# %%
hensu mei <- 3
123da <- 5
room-3 <- 7

# %% [markdown]
# なぜなら、
# hensu mei はスペースが間にあるのでだめ。
# 123de は最初の文字が英字ではありません。数字が許されるのは二文字目以後。
# そしげroom-3 の-も演算子なので、名前の一部にはなりません。

# %% [markdown]
# 以下もエラーになります。
#
# 代入の左辺は、変数である必要があります。数式を代入の左辺に使うことはできません。

# %%
room-3 <- 7

# %% [markdown]
# これなら大丈夫。

# %%
x <- 11
y <- 12

cat('x=',x, '    y=', y)

# %% [markdown]
# 日本語はつかえるようですが、多分あまり使わない方がよいかと思います。
#
# 理由1: いつも使えるとは限らない。
# 理由2: 海外の人に不親切。

# %% [markdown]
# ## 練習問題
#
# ただしい変数、間違った変数を2つずつ考えてください。

# %% [markdown]
# 以下の　--A-- の部分に3行の計算と代入をいれて、xとyを入れ替えてみてください。
# ~~~
# x <- 123
# y <- 456
# ---A---
# print(x)
# print(y)
# ~~~

# %% [markdown]
# # 2 printとcat
#
# すでにprintを使いましたが、以下のように cat を使うと文字列と変数の出力を組み合わせて見やすく表示することができます。
#
# cat 関数の引数はいくつあってもかまいません。
# 結果引数はすべて順番に出力されます。
# 改行は行われません。改行したいところで '\n' をいれます。

# %%
x <- 23
y <- 12
p456 = 789
cat("x=", x,'\n')
cat("y=", y,'\n')
cat("p456=",p456, '\n')

# %% [markdown]
# # 3 演算子
#
# 加減乗除などの記号は以下の通りです
#
#
# |  種別  |  記号  | 使用例 | 意味 |
# |:----:|:----:|-------|---------|
# | 加算、減算|   + , -| x + 3 | x 足す 3 |
# | 乗算、除算|   * , /| y / 2 | y 割る 2 |
# | 累乗 | ** | x ** 2 | x の 2乗 |

# %%
cat("123000+567 =", 123000+567, '\n')
cat("3*4 =", 3*4, '\n')
cat("4/3 =", 4/3, '\n')
cat("10**3=", 10**3, '\n')

# %% [markdown]
# # 4 ベクトル
#
# ベクトルを c(2,3,4,5,6) のようにあらわせます。
# このベクトルですが、R 言語では数学のベクトルと同じ意味だけでなく、様々な使い方をします。似ていますが、ちょっと違うと思ってください。
#
# ベクトルは一旦変数に代入されると、複数の数値の列になります。
# c(1,2)のように書きますが、c はベクトルだよという記号として使っているだけでそれ以外に意味はありません。
# したがって、print すると数値の列だけが表示されます。
#
# ベクトルへの計算は、すべての要素に対する計算結果の列になります。

# %%
x <- c(2,3,4,5,6)
print(x)
print(x + 1)
print(x* 10)

# %% [markdown]
# この後
#
# print( 式)
#
# で結果が
#
# ~~~
# [1] 25 35 45 55 65
# ~~~
#
#
# となるようにしてみましょう。

# %% [markdown]
# vector を使って False からなるベクトルを作ることもできます。False はまだ数値が入っていないことを表します。

# %%
x <- vector(length=5)
print(x)

# %% [markdown]
# 数値を一つ一つ与えるかわりに、数列を作ることもできます。
#
# 以下は、数列の例です。

# %%
print(1:3)
print(10:7)

# %% [markdown]
# rep を使うと同じ数のくりかえし、seq を使うと一定間隔の数列を作れます。

# %%
print(rep(1,3))
print(rep(0,5))
print(seq(2,12,3))
print(seq(10,-10,-3))

# %% [markdown]
# ## 練習問題
# 以下のような数列を作ってください。
#
# ~~~
# 1 6 11 16 21 26 31
# 999 998 997
# -55 -57 -59 -61
# ~~~

# %% [markdown]
# # 5 数値表現、文字列、paste
#
#
# R言語では小数は普通に小数点を使って表します。
# 指数表示は  123e4 のように e(数字) と書き表します。
# 文字列はシングルクオートかダブルクオートであらわします。

# %%
print(123.45)
print(123e4)
print(1e-2)
print(1e-44)
print('The quick brown fox...')

# %% [markdown]
# ## 練習問題
# 結果が 3 になるようにしてください

# %%
x <- 3e10
y <- ここを変更
print(x / y)

# %% [markdown]
# #6 配列
# 配列はarray で作成できます。dimの後はベクトルで、これは次元サイズの列になります。まず例をみてみましょう。

# %%
x <- array(0, dim=c(3))
print(x)

# %% [markdown]
# dim=c(3) なので長さ3の次元が1つの配列ができます。
#
# dim=c(2,2)なら2x2、dim=c(4,5,2)なら 4 x 5 x 2 の配列ができます。

# %%
print('array(0, dim=c(2,2))')
print(array(0, dim=c(2,2)))
print('array(0, dim=c(3,4,2))')
print(array(0, dim=c(3,4,2)))

# %% [markdown]
# 行列は matrix で作ることができます。
# 行列のサイズや行列内の数値は、ベクトルで指定することができます。

# %%
A <- matrix(c(c(1, 2), c(11,12)), c(2,2))
print(A)
A <- matrix(c(c(1, 2, 3), c(11,12,13)), c(3,2))
print(A)

# %% [markdown]
# ところで、array や matrix で数値を与えるベクトルはひとつにまとめてもかまいません。すべてのベクトルの値をつなげて使っていきます。

# %%
A <- matrix(c(c(1), c(11,12,13),c(21,22)), c(3,2))
print(A)

# %%
x <- array(c(c(1), c(11,12,13),c(21,22,23),c(31)),c(2,2,2))
print(x)

# %% [markdown]
# ## 練習問題
# 以下のmatrix を作ってください
#
# ~~~
#
#      [,1] [,2] [,3] [,4] [,5]
# [1,]    1    3    5    7    9
# [2,]    2    4    6    8   10
#
# ~~~

# %%
x <- matrix(ここを埋める)
print(x)
